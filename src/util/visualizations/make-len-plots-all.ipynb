# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline


for f_name in ["SNLI"]:#,  "MNLI-matched", "MNLI-mismatched", "SciTail", "JOCI", "ADD-1", "DPR", "FN+", "SPR", "MPE"]:
    df = pd.read_csv("../%s_top100_lens.csv" % (f_name), usecols=[1,2,3])

    plt.figure(figsize=(20,10))
    
    new_df = df[df['gold-lbl'] == 'entailment']
    #plt.plot(new_df['count'], new_df['len'])

    new_df = df[df['gold-lbl'] == 'neutral']
    plt.plot(new_df['count'], new_df['len'])
    
    new_df = df[df['gold-lbl'] == 'contradiction']
    #plt.plot(new_df['count'], new_df['len'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline


for f_name in ["SNLI",  "MNLI-matched", "MNLI-mismatched", "SciTail", "JOCI", "ADD-1", "DPR", "FN+", "SPR", "MPE"]:
    df = pd.read_csv("../%s_top100_lens.csv" % (f_name), usecols=[1,2,3])
    for lbl in set(df['gold-lbl']):

        plt.figure(figsize=(15,10))
        print f_name, lbl    
        new_df = df[df['gold-lbl'] == lbl]
        plt.plot(new_df['count'], new_df['len'])
        plt.show()
    #print f_name
    #plt.savefig('%s-len-graph.pdf' % (f_name))
    #plt.clf()
# Out:
# SNLI entailment
# SNLI neutral
# SNLI contradiction
# MNLI-matched entailment
# MNLI-matched neutral
# MNLI-matched contradiction
# MNLI-mismatched entailment
# MNLI-mismatched neutral
# MNLI-mismatched contradiction
# SciTail entailment
# SciTail neutral
# JOCI entailment
# JOCI neutral
# JOCI contradiction
# ADD-1 not-entailed
# ADD-1 entailed
# DPR not-entailed
# DPR entailed
# FN+ not-entailed
# FN+ entailed
# SPR not-entailed
# SPR entailed
# MPE entailment
# MPE neutral
# MPE contradiction
